// %%
await Bun.$`echo Hello bash!`;
console.table({
  "Bun version": Bun.version,
  OS: process.platform,
  Architecture: process.arch,
});
// Out:
// Hello bash!
// ┌──────────────┬────────┐
// │              │ Values │
// ├──────────────┼────────┤
// │  Bun version │ 1.3.10 │
// │           OS │ darwin │
// │ Architecture │ x64    │
// └──────────────┴────────┘

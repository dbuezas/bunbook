// %%
await Bun.$`echo Hello bash!`;
console.log("Hello console!");
console.table({
  Hello: "world!",
  "Bun version": Bun.version,
  OS: process.platform,
  Architecture: process.arch,
  "Working directory": process.cwd(),
});
// Out:
// Hello bash!
// Hello console!
// ┌───────────────────┬──────────────────────────────────────────────────────────┐
// │                   │ Values                                                   │
// ├───────────────────┼──────────────────────────────────────────────────────────┤
// │             Hello │ world!                                                   │
// │       Bun version │ 1.3.10                                                   │
// │                OS │ darwin                                                   │
// │      Architecture │ x64                                                      │
// │ Working directory │ /Users/davidbuezas/code/ts-notebook/examples/hello-world │
// └───────────────────┴──────────────────────────────────────────────────────────┘
